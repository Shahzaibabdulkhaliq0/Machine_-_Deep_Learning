# %% [markdown]
# <h1 style="color:orange; font-weight:bold">🛠️ Python & ML Environment Setup</h1>

# %% [markdown]
# <div align="center">
#
# <img src="01_installation.png" alt="Missing Values Handling — From Basic to Advanced" width="100%">
#
# </div>

# %% [markdown]
# This notebook covers the **basic installation and setup required for Python-based Data Science and Machine Learning**.
#
# ### 📚 What We Set Up
#
# - 🐍 Python Environment
# - 📓 Jupyter Notebook
# - 📊 Data Science Libraries
# - 🤖 Machine Learning Libraries
# - 📈 Data Visualization Tools
# - ⚙️ Required Packages & Dependencies
#
# ### 🎯 Goal
#
# The goal of this notebook is to prepare a **ready-to-use Python environment** for working with:
#
# **Python → Data Analysis → Data Visualization → Machine Learning**
#
# > 💡 **Rule:** A properly configured environment is the first step toward building and running Machine Learning projects successfully.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
reg.coef_
# Out:
# array([0.5, 0.5])
